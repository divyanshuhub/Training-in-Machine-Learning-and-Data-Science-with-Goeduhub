# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Techniques

# %% [markdown]
# 1) Imputation
#
# removing null values
# drop or replace by mean or median

# %% [markdown]
# 2) Handling Outliers
#  outlier= those who don't fit
# detect outlier
# visulizatoin
# stats methods
# -standard deviation
# -%

# %% [markdown]
# 3) log transformation
# -log

# %% [markdown]
# 4) Binning
#
# -create bins-prevent overfitting

# %% [markdown]
# 5) one hot encoding

# %% [markdown]
# 6) Group

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\apollo\Downloads\heights.csv")

# %%
df.head()
# Out:
#      name  height
# 0  mohit      5.3
# 1  sakshi     5.2
# 2   arun      5.1
# 3  varun      4.9
# 4     ani     7.1

# %%
max_threshhold = df['height'].quantile(0.95)
max_threshhold
# Out:
# 7.4799999999999995

# %%
df[df.height>max_threshhold]
# Out:
#       name  height
# 11  ramesh     8.0

# %%
min_threshhold = df['height'].quantile(0.05)
min_threshhold
# Out:
# 3.6050000000000004

# %%
df[df.height<min_threshhold]
# Out:
#    name  height
# 7  anil     1.2

# %%
#remove outlier

df[(df.height<max_threshhold) & (df.height>min_threshhold)]
# Out:
#       name  height
# 0   mohit      5.3
# 1   sakshi     5.2
# 2    arun      5.1
# 3   varun      4.9
# 4      ani     7.1
# 5    amit      6.4
# 6    amita     6.5
# 8   sudha      6.0
# 9      ram     5.1
# 10  kamal      5.6
# 12  lokesh     7.2
# 13   madhu     5.9

# %%
df2 = pd.read_csv(r"C:\Users\apollo\Downloads\Bengaluru_House_Data.csv")
df2.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df2.corr()
# Out:
#              bath   balcony     price
# bath     1.000000  0.204201  0.456345
# balcony  0.204201  1.000000  0.120355
# price    0.456345  0.120355  1.000000

# %%
df2.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df3 = df2.drop("area_type", axis='columns') + pd.get_dummies(df2["area_type"])
df3
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area  \
# 0                 NaN           NaN         NaN                   NaN
# 1                 NaN           NaN         NaN                   NaN
# 2                 NaN           NaN         NaN                   NaN
# 3                 NaN           NaN         NaN                   NaN
# 4                 NaN           NaN         NaN                   NaN
# ...               ...           ...         ...                   ...
# 13315             NaN           NaN         NaN                   NaN
# 13316             NaN           NaN         NaN                   NaN
# 13317             NaN           NaN         NaN                   NaN
# 13318             NaN           NaN         NaN                   NaN
# 13319             NaN           NaN         NaN                   NaN
#
#        availability  balcony  bath  location  price  size  society  total_sqft
# ...

# %%
df3.drop("area_type")
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area  \
# 0                 NaN           NaN         NaN                   NaN
# 1                 NaN           NaN         NaN                   NaN
# 2                 NaN           NaN         NaN                   NaN
# 3                 NaN           NaN         NaN                   NaN
# 4                 NaN           NaN         NaN                   NaN
# ...               ...           ...         ...                   ...
# 13315             NaN           NaN         NaN                   NaN
# 13316             NaN           NaN         NaN                   NaN
# 13317             NaN           NaN         NaN                   NaN
# 13318             NaN           NaN         NaN                   NaN
# 13319             NaN           NaN         NaN                   NaN
#
#        area_type  availability  balcony  bath  location  price  size  society  \
# ...

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
min_t,max_t = df2["price"].quantile([0.001,0.999])
min_t,max_t
# Out:
# (11.159500000000001, 2000.0)

# %%
 import seaborn as sns

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# z-score => how many standard deviation away a datapoint is
# z= (x-mean)/sd
# x:any datapoint

# %%
df["zscore"]= (df.height - df["height"].mean())/df["height"].std()

# %%
df
# Out:
#       name  height     zscor
# 0   mohit      5.3 -0.238392
# 1   sakshi     5.2 -0.301363
# 2    arun      5.1 -0.364335
# 3   varun      4.9 -0.490278
# 4      ani     7.1  0.895094
# 5    amit      6.4  0.454294
# 6    amita     6.5  0.517265
# 7     anil     1.2 -2.820220
# 8   sudha      6.0  0.202408
# 9      ram     5.1 -0.364335
# 10  kamal      5.6 -0.049478
# 11  ramesh     8.0  1.461837
# 12  lokesh     7.2  0.958065
# 13   madhu     5.9  0.139437
